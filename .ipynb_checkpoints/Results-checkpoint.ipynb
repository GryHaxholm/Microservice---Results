# %% [markdown]
# # Results processing

# %% [markdown]
# ## Data importing and initial handling

# %%
import json
from json import loads
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
with open("/Users/gryhaxholm/Documents/DTU - Kandidatpeciale /Programming/Microservice - FEM_LCA_calc/resultsFiles/Beams_GWP.json") as b:
    dataBeams = json.load(b)
with open("/Users/gryhaxholm/Documents/DTU - Kandidatpeciale /Programming/Microservice - FEM_LCA_calc/resultsFiles/Columns_GWP.json") as c:
    dataColumns = json.load(c)
with open("/Users/gryhaxholm/Documents/DTU - Kandidatpeciale /Programming/Microservice - FEM_LCA_calc/resultsFiles/Decks_GWP.json") as d:
    dataDecks = json.load(d)
with open("/Users/gryhaxholm/Documents/DTU - Kandidatpeciale /Programming/Microservice - FEM_LCA_calc/resultsFiles/Foundations_GWP.json") as f:
    dataFoundations = json.load(f)
with open("/Users/gryhaxholm/Documents/DTU - Kandidatpeciale /Programming/Microservice - FEM_LCA_calc/resultsFiles/Walls_GWP.json") as w:
    dataWalls = json.load(w)

# %%
df_Beams = pd.DataFrame(dataBeams, index=['Beams'])
df_Columns = pd.DataFrame(dataColumns, index=['Columns'])
df_Decks = pd.DataFrame(dataDecks, index=['Decks'])
df_Foundations = pd.DataFrame(dataFoundations, index=['Foundations'])
df_Walls = pd.DataFrame(dataWalls, index=['Walls'])
print(df_Foundations)
print(df_Beams)
print(df_Columns)
print(df_Decks)
print(df_Walls)
# Out:
#                 A1-A3   C3        C4          D      Total
# Foundations  75.46436  0.0  0.075694 -43.613961  31.926093
#             A1-A3         C3        C4          D       Total
# Beams  248.140404  26.035434  3.127786 -75.489707  201.813918
#               A1-A3        C3        C4          D       Total
# Columns  282.283663  115.3237  4.080304 -149.20901  252.478657
#             A1-A3           C3         C4            D        Total
# Decks  240.239891  4176.873544  67.016626 -2619.337983  1864.792079
#            A1-A3        C3         C4           D        Total
# Walls  283.46436  1505.968  37.011694 -819.741961  1006.702093

# %% [markdown]
# ## Bar charts for GWP for groups of structural elements

# %%
plt.figure(figsize=(7,5))

plt.title("GWP for all beams", fontsize=20)
plt.xlabel("Life Cycle Phases", fontsize=12)
plt.ylabel("GWP [kgCO2e]",fontsize=12)
plt.style.use('dark_background')

df_Beams.iloc[0].plot.bar(color=["#00FF7F","#00FF7F","#00FF7F","#00FF7F","#FFFF00"])
# Out:
# <AxesSubplot: title={'center': 'GWP for all beams'}, xlabel='Life Cycle Phases', ylabel='GWP [kgCO2e]'>

# %%
plt.figure(figsize=(7,5))

plt.title("GWP for all columns", fontsize=20)
plt.xlabel("Life Cycle Phases", fontsize=12)
plt.ylabel("GWP [kgCO2e]",fontsize=12)

df_Columns.iloc[0].plot.bar(color=["#00FF7F","#00FF7F","#00FF7F","#00FF7F","#FFFF00"])
# Out:
# <AxesSubplot: title={'center': 'GWP for all columns'}, xlabel='Life Cycle Phases', ylabel='GWP [kgCO2e]'>

# %%
plt.figure(figsize=(15,10))

plt.title("GWP for all decks", fontsize=20)
plt.xlabel("Life Cycle Phases", fontsize=12)
plt.ylabel("GWP [kgCO2e]",fontsize=12)

df_Decks.iloc[0].plot.bar(color=["#00FF7F","#00FF7F","#00FF7F","#00FF7F","#FFFF00"])
# Out:
# <AxesSubplot: title={'center': 'GWP for all decks'}, xlabel='Life Cycle Phases', ylabel='GWP [kgCO2e]'>

# %%
plt.figure(figsize=(15,10))

plt.title("GWP for all foundations", fontsize=20)
plt.xlabel("Life Cycle Phases", fontsize=12)
plt.ylabel("GWP [kgCO2e]",fontsize=12)

df_Foundations.iloc[0].plot.bar(color=["#00FF7F","#00FF7F","#00FF7F","#00FF7F","#FFFF00"])
# Out:
# <AxesSubplot: title={'center': 'GWP for all foundations'}, xlabel='Life Cycle Phases', ylabel='GWP [kgCO2e]'>

# %%
plt.figure(figsize=(15,10))

plt.title("GWP for all walls", fontsize=20)
plt.xlabel("Life Cycle Phases", fontsize=12)
plt.ylabel("GWP [kgCO2e]",fontsize=12)

df_Walls.iloc[0].plot.bar(color=["#00FF7F","#00FF7F","#00FF7F","#00FF7F","#FFFF00"])
# Out:
# <AxesSubplot: title={'center': 'GWP for all walls'}, xlabel='Life Cycle Phases', ylabel='GWP [kgCO2e]'>

# %% [markdown]
# ## Bar charts for GWP across structural elements

# %%
dfAll = [df_Beams,df_Columns, df_Decks,df_Foundations, df_Walls]
df_All = pd.concat(dfAll, join='outer')
df_All
# Out:
#                   A1-A3           C3         C4            D        Total
# Beams        266.545284    26.035434   3.146247   -86.126645   209.600320
# Columns      229.191303   115.323700   4.027050  -118.524749   230.017304
# Decks        866.519891  4188.429544  75.440626 -2627.041983  2503.348079
# Foundations    0.000000     0.000000   0.000000     0.000000     0.000000
# Walls        283.464360  1505.968000  37.011694  -819.741961  1006.702093

# %%
weight = 0.30

df_All.plot(kind="bar", color = ["green", "red", "yellow", "blue", "orange"], figsize=(15,10))
plt.title("GWP for all structural elements", fontsize = 20)
plt.legend(loc="upper left", fontsize=14)
plt.xlabel("Element category", fontsize =14)
plt.ylabel("GWP [kgCO2e]", fontsize=14)
plt.show()

# %%
df_All_Pivot=pd.pivot_table(df_All, columns=['Beams','Columns','Decks', 'Foundations', 'Walls'], values=['A1-A3','C3','C4','D','Total'], aggfunc=np.sum)
print(df_All_Pivot)
# Out:
#             Beams     Columns        Decks  Foundations        Walls
# A1-A3  266.545284  229.191303   866.519891          0.0   283.464360
# C3      26.035434  115.323700  4188.429544          0.0  1505.968000
# C4       3.146247    4.027050    75.440626          0.0    37.011694
# D      -86.126645 -118.524749 -2627.041983          0.0  -819.741961
# Total  209.600320  230.017304  2503.348079          0.0  1006.702093

# %%
df_All_Pivot.plot(kind="bar", color = ["#00FF7F", "#CD0000","#FFFF00","Blue","#FF1493"], figsize=(15,10))
plt.title("GWP for all structural elements", fontsize = 20)
plt.legend(loc="upper left", fontsize=14)
plt.xlabel("Element category", fontsize =14)
plt.ylabel("GWP [kgCO2e]", fontsize=14)
for i, g in enumerate(df_All_Pivot['Beams']):
    plt.text(i, g-8, int(float(f'{g}')),ha='right', fontsize=14)
for i, g in enumerate(df_All_Pivot['Columns']):
    plt.text(i, g-8, int(float(f'{g}')),ha='left', fontsize=14)
for i, g in enumerate(df_All_Pivot['Decks']):
    plt.text(i, g-8, int(float(f'{g}')),ha='left', fontsize=14)
for i, g in enumerate(df_All_Pivot['Foundations']):
    plt.text(i, g-8, int(float(f'{g}')),ha='left', fontsize=14)
for i, g in enumerate(df_All_Pivot['Walls']):
    plt.text(i, g-8, int(float(f'{g}')),ha='left', fontsize=14)
plt.show()

# %% [markdown]
# ## Scatter plots for GWP for groups of structural elements

# %%
with open("/Users/gryhaxholm/Documents/DTU - Kandidatpeciale /Programming/Microservice - FEM_LCA_calc/Beams_list.json") as bl:
    dataBeamList = json.load(bl)

df_BeamList = pd.DataFrame(dataBeamList)
    
df_BeamList.columns=['Type ID', 'A1-A3', 'C3', 'C4', 'D']
print(df_BeamList)
# Out:
#   Type ID      A1-A3         C3        C4          D
# 0     B.2  51.600000   1.665600  1.231200  -1.137600
# 1     B.3  77.400000   2.498400  1.846800  -1.706400
# 2     F.1  34.142120   0.000000  0.034246 -19.732137
# 3     F.1  33.898000   0.000000  0.034001 -19.591050
# 4     B.1  89.499375   0.146381  0.000000 -32.888037
# 5     B.4 -19.994211  21.725053  0.000000 -11.071421

# %%
with open("/Users/gryhaxholm/Documents/DTU - Kandidatpeciale /Programming/Microservice - FEM_LCA_calc/Columns_list.json") as cl:
    dataColumnList = json.load(cl)

df_ColumnList = pd.DataFrame(dataColumnList)
    
df_ColumnList.columns=['Type ID', 'A1-A3', 'C3', 'C4', 'D']
print(df_ColumnList)
# Out:
#    Type ID       A1-A3         C3       C4          D
# 0      C.3  125.775000   4.059900  3.00105  -2.772900
# 1      C.6    9.245000   0.298420  0.22059  -0.203820
# 2      C.7   14.405000   0.464980  0.34371  -0.317580
# 3      T.3   19.350000   0.624600  0.46170  -0.426600
# 4      C.8   37.564875   0.061439  0.00000 -13.803839
# 5      T.1   51.874875   0.084844  0.00000 -19.062287
# 6      T.2   69.597000   0.113830  0.00000 -25.574578
# 7      C.1  -18.696500  22.772950  0.00000 -12.106750
# 8      C.2   -6.611842   7.184211  0.00000  -3.661184
# 9      C.4  -36.656053  39.829263  0.00000 -20.297605
# 10     C.5  -36.656053  39.829263  0.00000 -20.297605

# %%
with open("/Users/gryhaxholm/Documents/DTU - Kandidatpeciale /Programming/Microservice - FEM_LCA_calc/Decks_list.json") as dl:
    dataDeckList = json.load(dl)

df_DeckList = pd.DataFrame(dataDeckList)
    
df_DeckList.columns=['Type ID', 'A1-A3', 'C3', 'C4', 'D']
print(df_DeckList)
# Out:
#   Type ID        A1-A3           C3         C4            D
# 0     P.1  2064.000000    66.624000  49.248000   -45.504000
# 1   P.1.1   772.753360     0.000000   0.775106  -446.605986
# 2   P.1.1    49.370040     0.000000   0.049520   -28.532979
# 3   P.2.1 -3761.403509  4087.017544   0.000000 -2082.807018
# 4    PP.1   258.960000     5.376000   3.912000    -3.684000
# 5    PP.1   494.280000     9.804000   7.152000    -6.636000
# 6    TP.1   494.280000     9.804000   7.152000    -6.636000
# 7    TP.1   494.280000     9.804000   7.152000    -6.636000

# %%
with open("/Users/gryhaxholm/Documents/DTU - Kandidatpeciale /Programming/Microservice - FEM_LCA_calc/Foundations_list.json") as fl:
    dataFoundationList = json.load(fl)

df_FoundationList = pd.DataFrame(dataFoundationList)
    
df_FoundationList.columns=['Type ID', 'A1-A3', 'C3', 'C4', 'D']
print(df_FoundationList)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 6
#       2     dataFoundationList = json.load(fl)
#       4 df_FoundationList = pd.DataFrame(dataFoundationList)
# ----> 6 df_FoundationList.columns=['Type ID', 'A1-A3', 'C3', 'C4', 'D']
#       7 print(df_FoundationList)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %%
with open("/Users/gryhaxholm/Documents/DTU - Kandidatpeciale /Programming/Microservice - FEM_LCA_calc/Walls_list.json") as wl:
    dataWallList = json.load(wl)

df_WallList = pd.DataFrame(dataWallList)
    
df_WallList.columns=['Type ID', 'A1-A3', 'C3', 'C4', 'D']
print(df_WallList)
# Out:
#   Type ID       A1-A3        C3         C4           D
# 0     W.1  1032.00000    33.312  24.624000  -22.752000
# 1     W.2   516.00000    16.656  12.312000  -11.376000
# 2   W.1.1    50.30980     0.000   0.050463  -29.076105
# 3   W.2.1    25.15456     0.000   0.025231  -14.537856
# 4   W.3.1 -1340.00000  1456.000   0.000000 -742.000000

# %%
df_BeamList.plot(kind="scatter", x='Type ID', y='A1-A3', color="#00FF",figsize=(10,7))
plt.title("GWP for beams", fontsize = 20)
plt.xlabel("Beam Type ID", fontsize =14)
plt.ylabel("GWP [kgCO2e]", fontsize=14)
for i, g in enumerate(df_BeamList['A1-A3']):
    plt.text(i, g-8, int(float(f'{g}')),ha='center', fontsize=14)7F
plt.show()

# %%
df_ColumnList.plot(kind="scatter", x='Type ID', y='A1-A3', color="#00FF7F",figsize=(10,7))
plt.title("GWP for columns", fontsize = 20)
plt.xlabel("Column Type ID", fontsize =14)
plt.ylabel("GWP [kgCO2e]", fontsize=14)
for i, g in enumerate(df_ColumnList['A1-A3']):
    plt.text(i, g-8, int(float(f'{g}')),ha='center', fontsize=14)
plt.show()

# %%
df_DeckList.plot(kind="scatter", x='Type ID', y='A1-A3', color="#00FF7F",figsize=(10,7))
plt.title("GWP for decks", fontsize = 20)
plt.xlabel("Deck Type ID", fontsize =14)
plt.ylabel("GWP [kgCO2e]", fontsize=14)
for i, g in enumerate(df_DeckList['A1-A3']):
    plt.text(i, g-8, int(float(f'{g}')),ha='center', fontsize=14)
plt.show()

# %%
df_FoundationList.plot(kind="scatter", x='Type ID', y='A1-A3', color="#00FF7F",figsize=(10,7))
plt.title("GWP for foundations", fontsize = 20)
plt.xlabel("Foundation Type ID", fontsize =14)
plt.ylabel("GWP [kgCO2e]", fontsize=14)
for i, g in enumerate(df_FoundationList['A1-A3']):
    plt.text(i, g-8, int(float(f'{g}')),ha='center', fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df_FoundationList.plot(kind="scatter", x='Type ID', y='A1-A3', color="#00FF7F",figsize=(10,7))
#       2 plt.title("GWP for foundations", fontsize = 20)
#       3 plt.xlabel("Foundation Type ID", fontsize =14)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/plotting/_core.py:945, in PlotAccessor.__call__(self, *args, **kwargs)
#     943 if kind in self._dataframe_kinds:
#     944     if isinstance(data, ABCDataFrame):
# --> 945         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     946     else:
#     947         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ...

# %%
df_WallList.plot(kind="scatter", x='Type ID', y='A1-A3', color="#00FF7F",figsize=(10,7))
plt.title("GWP for walls", fontsize = 20)
plt.xlabel("Wall Type ID", fontsize =14)
plt.ylabel("GWP [kgCO2e]", fontsize=14)
for i, g in enumerate(df_WallList['A1-A3']):
    plt.text(i, g-8, int(float(f'{g}')),ha='center', fontsize=14)
plt.show()

# %% [markdown]
# Trial charts

# %%
plt.figure(figsize=(7,5))

plt.title("GWP for all beams", fontsize=20)
plt.xlabel("Life Cycle Phases", fontsize=14)
plt.ylabel("GWP [kgCO2e]",fontsize=14)
plt.style.use('_mpl-gallery-nogrid')
plt.hlines(0,-1,5,color='grey', linewidth=1)
for i, g in enumerate(df_Beams.iloc[0]):
    plt.text(i, g+5, int(float(f'{g}')),ha='center', fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

df_Beams.iloc[0].plot.bar(width=0.3, color='#228B22')
# Out:
# <AxesSubplot: title={'center': 'GWP for all beams'}, xlabel='Life Cycle Phases', ylabel='GWP [kgCO2e]'>

# %%
df_All_Pivot.plot(kind="bar", figsize=(15,10))
plt.title("GWP for all structural elements", fontsize = 20)
plt.legend(loc="upper left", fontsize=14)
plt.xlabel("Element category", fontsize =14)
plt.ylabel("GWP [kgCO2e]", fontsize=14)
plt.style.use('_mpl-gallery-nogrid')
for i, g in enumerate(df_All_Pivot['Beams']):
    plt.text(i, g+5, int(float(f'{g}')),ha='left', fontsize=14)
for i, g in enumerate(df_All_Pivot['Columns']):
    plt.text(i, g+5, int(float(f'{g}')),ha='left', fontsize=14)
for i, g in enumerate(df_All_Pivot['Decks']):
    plt.text(i, g+5, int(float(f'{g}')),ha='center', fontsize=14)
for i, g in enumerate(df_All_Pivot['Foundations']):
    plt.text(i, g+5, int(float(f'{g}')),ha='right', fontsize=14)
for i, g in enumerate(df_All_Pivot['Walls']):
    plt.text(i, g+5, int(float(f'{g}')),ha='right', fontsize=14)
plt.show()

# %%
df_ColumnList.plot(kind="scatter", x='Type ID', y='A1-A3', s=100, color="#228B22",figsize=(10,7))
plt.title("GWP for columns", fontsize = 20)
plt.xlabel("Column Type ID", fontsize =14)
plt.ylabel("GWP [kgCO2e]", fontsize=14)
for i, g in enumerate(df_ColumnList['A1-A3']):
    plt.text(i, g+5, int(float(f'{g}')),ha='center', fontsize=14)
plt.style.use('_mpl-gallery-nogrid')
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
